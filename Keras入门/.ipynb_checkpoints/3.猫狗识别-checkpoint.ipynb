# %%
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\zsx\Anaconda3\lib\site-packages\h5py\__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
from data_loader import load_data
(x_train, y_train), (x_test, y_test) = load_data()

# %%
plt.imshow(x_train[0])
plt.show()

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (402, 64, 64, 3)
# (402, 1)
# (40, 64, 64, 3)
# (40, 1)

# %%
x_train = x_train.reshape(x_train.shape[0], -1)
x_test = x_test.reshape(x_test.shape[0], -1)
x_train.shape
# Out:
# (402, 12288)

# %%
#(n,12288)*(12288,128)=(n,128)
#(n,128)*(128,64)=(n,64)
#(n,64)*(64,32)=(n,32)
#(n,32)*(32,16)=(n,16)
#(n,16)*(16,1)=(n,1)
cat_model = Sequential()
cat_model.add(Dense(128, activation='relu', input_shape=(12288,)))
cat_model.add(Dense(64, activation='relu'))
cat_model.add(Dense(32, activation='relu'))
cat_model.add(Dense(16, activation='relu'))
cat_model.add(Dense(1, activation='sigmoid'))

# %%
cat_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               1572992
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                528
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 1,583,873
# Trainable params: 1,583,873
# Non-trainable params: 0
# _________________________________________________________________

# %%
cat_model.compile(optimizer=SGD(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
cat_model.fit(x_train, y_train,epochs=40 ,validation_data=(x_test, y_test))
# Out:
# Train on 402 samples, validate on 40 samples
# Epoch 1/40
# 402/402 [==============================] - 1s 2ms/step - loss: 0.6958 - acc: 0.4876 - val_loss: 0.6947 - val_acc: 0.5250
# Epoch 2/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6895 - acc: 0.5398 - val_loss: 0.6947 - val_acc: 0.5500
# Epoch 3/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6864 - acc: 0.5771 - val_loss: 0.6939 - val_acc: 0.4250
# Epoch 4/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6810 - acc: 0.6045 - val_loss: 0.6971 - val_acc: 0.5500
# Epoch 5/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6802 - acc: 0.6045 - val_loss: 0.6925 - val_acc: 0.5500
# Epoch 6/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6778 - acc: 0.5871 - val_loss: 0.6998 - val_acc: 0.4500
# Epoch 7/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6699 - acc: 0.6318 - val_loss: 0.7252 - val_acc: 0.5250
# Epoch 8/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6615 - acc: 0.6294 - val_loss: 0.7383 - val_acc: 0.5250
# Epoch 9/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6565 - acc: 0.6418 - val_loss: 0.7167 - val_acc: 0.5250
# Epoch 10/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6516 - acc: 0.6368 - val_loss: 0.7564 - val_acc: 0.5250
# Epoch 11/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6389 - acc: 0.6418 - val_loss: 0.7109 - val_acc: 0.4750
# Epoch 12/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6575 - acc: 0.6318 - val_loss: 0.7000 - val_acc: 0.5000
# Epoch 13/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6393 - acc: 0.6443 - val_loss: 0.7075 - val_acc: 0.4250
# Epoch 14/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6271 - acc: 0.6841 - val_loss: 0.7169 - val_acc: 0.5250
# Epoch 15/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6328 - acc: 0.6493 - val_loss: 0.7383 - val_acc: 0.5250
# Epoch 16/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6210 - acc: 0.6716 - val_loss: 0.7259 - val_acc: 0.4500
# Epoch 17/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6064 - acc: 0.6866 - val_loss: 0.7816 - val_acc: 0.5250
# Epoch 18/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5898 - acc: 0.7040 - val_loss: 0.7728 - val_acc: 0.5000
# Epoch 19/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5948 - acc: 0.6766 - val_loss: 0.7717 - val_acc: 0.4750
# Epoch 20/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6083 - acc: 0.6841 - val_loss: 0.9187 - val_acc: 0.5000
# Epoch 21/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5916 - acc: 0.6841 - val_loss: 0.7540 - val_acc: 0.5000
# Epoch 22/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6147 - acc: 0.6716 - val_loss: 0.8099 - val_acc: 0.5250
# Epoch 23/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.6072 - acc: 0.6990 - val_loss: 0.8046 - val_acc: 0.5000
# Epoch 24/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5709 - acc: 0.7040 - val_loss: 0.8398 - val_acc: 0.5500
# Epoch 25/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5458 - acc: 0.7338 - val_loss: 0.7115 - val_acc: 0.5500
# Epoch 26/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5158 - acc: 0.7836 - val_loss: 0.7987 - val_acc: 0.4500
# Epoch 27/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5878 - acc: 0.6915 - val_loss: 0.7225 - val_acc: 0.5250
# Epoch 28/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5844 - acc: 0.6766 - val_loss: 0.7317 - val_acc: 0.5000
# Epoch 29/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5256 - acc: 0.7289 - val_loss: 0.7618 - val_acc: 0.5250
# Epoch 30/40
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5423 - acc: 0.7189 - val_loss: 0.7363 - val_acc: 0.5000
# Epoch 31/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5366 - acc: 0.7363 - val_loss: 0.7840 - val_acc: 0.4500
# Epoch 32/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5164 - acc: 0.7413 - val_loss: 0.7332 - val_acc: 0.5000
# Epoch 33/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5373 - acc: 0.7289 - val_loss: 0.7600 - val_acc: 0.5250
# Epoch 34/40
# 402/402 [==============================] - 1s 1ms/step - loss: 0.4721 - acc: 0.8109 - val_loss: 0.7384 - val_acc: 0.6000
# Epoch 35/40
# 402/402 [==============================] - 1s 1ms/step - loss: 0.5391 - acc: 0.7512 - val_loss: 0.8828 - val_acc: 0.4500
# Epoch 36/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.4944 - acc: 0.7736 - val_loss: 0.8491 - val_acc: 0.5750
# Epoch 37/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.4896 - acc: 0.7662 - val_loss: 0.8433 - val_acc: 0.4500
# Epoch 38/40
# 402/402 [==============================] - 0s 995us/step - loss: 0.4903 - acc: 0.7662 - val_loss: 0.7693 - val_acc: 0.5500
# Epoch 39/40
# 402/402 [==============================] - 0s 995us/step - loss: 0.5000 - acc: 0.7463 - val_loss: 0.9115 - val_acc: 0.4750
# Epoch 40/40
# 402/402 [==============================] - 0s 1ms/step - loss: 0.5490 - acc: 0.7239 - val_loss: 0.8549 - val_acc: 0.5500

# %%
from skimage.transform import resize
fig=plt.figure(figsize=(16, 16))
for i in range(1, 10):
    my_image =  'data/images/test/{}.jpg'.format(i)
    my_image = np.array(plt.imread(my_image))
    ax = fig.add_subplot(4, 5, i)
    plt.imshow(my_image)
    num_px = 64
    my_image = resize(my_image, (num_px, num_px))
    print(my_image.shape)
    my_image = my_image.reshape(1, -1)
    a = cat_model.predict(my_image)
    if  a > 0.5:
        ax.title.set_text('cat {}'.format(a))
    else:
        ax.title.set_text('dog {}'.format(1 - a))   
plt.show()
print(cat_model.evaluate(x_test, y_test))
# Out:
# C:\Users\zsx\Anaconda3\lib\site-packages\skimage\transform\_warps.py:84: UserWarning: The default mode, 'constant', will be changed to 'reflect' in skimage 0.15.
#   warn("The default mode, 'constant', will be changed to 'reflect' in "
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# (64, 64, 3)
# 40/40 [==============================] - 0s 500us/step
# [0.8548932492733001, 0.55]
